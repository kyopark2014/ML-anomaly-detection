# %% [markdown]
# # AWS CloudWatch Logs
#
# Link: [NAB/data/realAWSCloudwatch](https://github.com/numenta/NAB/tree/master/data/realAWSCloudwatch)
#
# Link: [Anomaly Detection : Isolation Forest with Statistical Rules](https://towardsdatascience.com/isolation-forest-with-statistical-rules-4dd27dad2da9)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
ec2_cpu_utilization_24ae8d = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_24ae8d.csv')
ec2_cpu_utilization_24ae8d.head()
# Out:
#              timestamp  value
# 0  2014-02-14 14:30:00  0.132
# 1  2014-02-14 14:35:00  0.134
# 2  2014-02-14 14:40:00  0.134
# 3  2014-02-14 14:45:00  0.134
# 4  2014-02-14 14:50:00  0.134

# %%
print(ec2_cpu_utilization_24ae8d['timestamp'].min())
print(ec2_cpu_utilization_24ae8d['timestamp'].max())
print(len(ec2_cpu_utilization_24ae8d['timestamp']))
# Out:
# 2014-02-14 14:30:00
# 2014-02-28 14:25:00
# 4032

# %%
ec2_cpu_utilization_24ae8d.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_53ea38 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_53ea38.csv')
ec2_cpu_utilization_53ea38.head()
# Out:
#              timestamp  value
# 0  2014-02-14 14:30:00  1.732
# 1  2014-02-14 14:35:00  1.732
# 2  2014-02-14 14:40:00  1.960
# 3  2014-02-14 14:45:00  1.732
# 4  2014-02-14 14:50:00  1.706

# %%
print(ec2_cpu_utilization_53ea38['timestamp'].min())
print(ec2_cpu_utilization_53ea38['timestamp'].max())
print(len(ec2_cpu_utilization_53ea38['timestamp']))
# Out:
# 2014-02-14 14:30:00
# 2014-02-28 14:25:00
# 4032

# %%
ec2_cpu_utilization_53ea38.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_5f5533 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_5f5533.csv')
ec2_cpu_utilization_5f5533.head()
# Out:
#              timestamp   value
# 0  2014-02-14 14:27:00  51.846
# 1  2014-02-14 14:32:00  44.508
# 2  2014-02-14 14:37:00  41.244
# 3  2014-02-14 14:42:00  48.568
# 4  2014-02-14 14:47:00  46.714

# %%
print(ec2_cpu_utilization_5f5533['timestamp'].min())
print(ec2_cpu_utilization_5f5533['timestamp'].max())
print(len(ec2_cpu_utilization_5f5533['timestamp']))
# Out:
# 2014-02-14 14:27:00
# 2014-02-28 14:22:00
# 4032

# %%
ec2_cpu_utilization_5f5533.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_77c1ca = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_77c1ca.csv')
ec2_cpu_utilization_77c1ca.head()
# Out:
#              timestamp  value
# 0  2014-04-02 14:25:00  0.068
# 1  2014-04-02 14:30:00  0.102
# 2  2014-04-02 14:35:00  0.100
# 3  2014-04-02 14:40:00  0.098
# 4  2014-04-02 14:45:00  0.102

# %%
print(ec2_cpu_utilization_77c1ca['timestamp'].min())
print(ec2_cpu_utilization_77c1ca['timestamp'].max())
print(len(ec2_cpu_utilization_77c1ca['timestamp']))
# Out:
# 2014-04-02 14:25:00
# 2014-04-16 14:20:00
# 4032

# %%
ec2_cpu_utilization_77c1ca.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_825cc2 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_825cc2.csv')
ec2_cpu_utilization_825cc2.head()
# Out:
#              timestamp   value
# 0  2014-04-10 00:04:00  91.958
# 1  2014-04-10 00:09:00  94.798
# 2  2014-04-10 00:14:00  92.208
# 3  2014-04-10 00:19:00  93.722
# 4  2014-04-10 00:24:00  93.042

# %%
print(ec2_cpu_utilization_825cc2['timestamp'].min())
print(ec2_cpu_utilization_825cc2['timestamp'].max())
print(len(ec2_cpu_utilization_825cc2['timestamp']))
# Out:
# 2014-04-10 00:04:00
# 2014-04-24 00:09:00
# 4032

# %%
ec2_cpu_utilization_825cc2.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_ac20cd = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_ac20cd.csv')
ec2_cpu_utilization_ac20cd.head()
# Out:
#              timestamp   value
# 0  2014-04-02 14:29:00  42.652
# 1  2014-04-02 14:34:00  41.362
# 2  2014-04-02 14:39:00  43.408
# 3  2014-04-02 14:44:00  40.262
# 4  2014-04-02 14:49:00  40.328

# %%
print(ec2_cpu_utilization_ac20cd['timestamp'].min())
print(ec2_cpu_utilization_ac20cd['timestamp'].max())
print(len(ec2_cpu_utilization_ac20cd['timestamp']))
# Out:
# 2014-04-02 14:29:00
# 2014-04-16 14:49:00
# 4032

# %%
ec2_cpu_utilization_ac20cd.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_c6585a = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_c6585a.csv')
ec2_cpu_utilization_c6585a.head()
# Out:
#              timestamp  value
# 0  2014-04-02 14:29:00  0.066
# 1  2014-04-02 14:34:00  0.066
# 2  2014-04-02 14:39:00  0.068
# 3  2014-04-02 14:44:00  0.134
# 4  2014-04-02 14:49:00  0.066

# %%
print(ec2_cpu_utilization_c6585a['timestamp'].min())
print(ec2_cpu_utilization_c6585a['timestamp'].max())
print(len(ec2_cpu_utilization_c6585a['timestamp']))
# Out:
# 2014-04-02 14:29:00
# 2014-04-16 14:24:00
# 4032

# %%
ec2_cpu_utilization_c6585a.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_cpu_utilization_fe7f93 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_cpu_utilization_fe7f93.csv')
ec2_cpu_utilization_fe7f93.head()
# Out:
#              timestamp  value
# 0  2014-02-14 14:27:00  2.296
# 1  2014-02-14 14:32:00  2.144
# 2  2014-02-14 14:37:00  2.274
# 3  2014-02-14 14:42:00  2.066
# 4  2014-02-14 14:47:00  2.350

# %%
print(ec2_cpu_utilization_fe7f93['timestamp'].min())
print(ec2_cpu_utilization_fe7f93['timestamp'].max())
print(len(ec2_cpu_utilization_fe7f93['timestamp']))
# Out:
# 2014-02-14 14:27:00
# 2014-02-28 14:22:00
# 4032

# %%
ec2_cpu_utilization_fe7f93.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_disk_write_bytes_1ef3de = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_disk_write_bytes_1ef3de.csv')
ec2_disk_write_bytes_1ef3de.head()
# Out:
#              timestamp  value
# 0  2014-03-01 17:34:00    0.0
# 1  2014-03-01 17:39:00    0.0
# 2  2014-03-01 17:44:00    0.0
# 3  2014-03-01 17:49:00    0.0
# 4  2014-03-01 17:54:00    0.0

# %%
print(ec2_disk_write_bytes_1ef3de['timestamp'].min())
print(ec2_disk_write_bytes_1ef3de['timestamp'].max())
print(len(ec2_disk_write_bytes_1ef3de['timestamp']))
# Out:
# 2014-03-01 17:34:00
# 2014-03-18 03:39:00
# 4730

# %%
ec2_disk_write_bytes_1ef3de.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_disk_write_bytes_c0d644 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_disk_write_bytes_c0d644.csv')
ec2_disk_write_bytes_c0d644.head()
# Out:
#              timestamp  value
# 0  2014-04-02 14:25:00    0.0
# 1  2014-04-02 14:30:00    0.0
# 2  2014-04-02 14:35:00    0.0
# 3  2014-04-02 14:40:00    0.0
# 4  2014-04-02 14:45:00    0.0

# %%
print(ec2_disk_write_bytes_c0d644['timestamp'].min())
print(ec2_disk_write_bytes_c0d644['timestamp'].max())
print(len(ec2_disk_write_bytes_c0d644['timestamp']))
# Out:
# 2014-04-02 14:25:00
# 2014-04-16 14:20:00
# 4032

# %%
ec2_disk_write_bytes_c0d644.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_network_in_257a54 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_network_in_257a54.csv')
ec2_network_in_257a54.head()
# Out:
#              timestamp      value
# 0  2014-04-10 00:04:00   251643.0
# 1  2014-04-10 00:09:00  3203510.0
# 2  2014-04-10 00:14:00   287397.0
# 3  2014-04-10 00:19:00   238944.0
# 4  2014-04-10 00:24:00   245880.0

# %%
print(ec2_network_in_257a54['timestamp'].min())
print(ec2_network_in_257a54['timestamp'].max())
print(len(ec2_network_in_257a54['timestamp']))
# Out:
# 2014-04-10 00:04:00
# 2014-04-24 00:09:00
# 4032

# %%
ec2_network_in_257a54.plot()
# Out:
# <AxesSubplot: >

# %%
ec2_network_in_5abac7 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/ec2_network_in_5abac7.csv')
ec2_network_in_5abac7.head()
# Out:
#              timestamp  value
# 0  2014-03-01 17:36:00   42.0
# 1  2014-03-01 17:41:00   94.8
# 2  2014-03-01 17:46:00   42.0
# 3  2014-03-01 17:51:00   68.4
# 4  2014-03-01 17:56:00   68.4

# %%
print(ec2_network_in_5abac7['timestamp'].min())
print(ec2_network_in_5abac7['timestamp'].max())
print(len(ec2_network_in_5abac7['timestamp']))
# Out:
# 2014-03-01 17:36:00
# 2014-03-18 03:41:00
# 4730

# %%
ec2_cpu_utilization_5f5533.plot()
# Out:
# <AxesSubplot: >

# %%
elb_request_count_8c0756 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/elb_request_count_8c0756.csv')
elb_request_count_8c0756.head()
# Out:
#              timestamp  value
# 0  2014-04-10 00:04:00   94.0
# 1  2014-04-10 00:09:00   56.0
# 2  2014-04-10 00:14:00  187.0
# 3  2014-04-10 00:19:00   95.0
# 4  2014-04-10 00:24:00   51.0

# %%
print(elb_request_count_8c0756['timestamp'].min())
print(elb_request_count_8c0756['timestamp'].max())
print(len(elb_request_count_8c0756['timestamp']))
# Out:
# 2014-04-10 00:04:00
# 2014-04-24 00:39:00
# 4032

# %%
elb_request_count_8c0756.plot()
# Out:
# <AxesSubplot: >

# %%
grok_asg_anomaly = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/grok_asg_anomaly.csv')
grok_asg_anomaly.head()
# Out:
#              timestamp    value
# 0  2014-01-16 00:00:00  33.5573
# 1  2014-01-16 00:05:00  33.4460
# 2  2014-01-16 00:10:00  33.4447
# 3  2014-01-16 00:15:00  33.3333
# 4  2014-01-16 00:20:00  33.4447

# %%
print(grok_asg_anomaly['timestamp'].min())
print(grok_asg_anomaly['timestamp'].max())
print(len(grok_asg_anomaly['timestamp']))
# Out:
# 2014-01-16 00:00:00
# 2014-02-01 01:00:00
# 4621

# %%
grok_asg_anomaly.plot()
# Out:
# <AxesSubplot: >

# %%
NetworkIn = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/iio_us-east-1_i-a2eb1cd9_NetworkIn.csv')
NetworkIn.head()
# Out:
#              timestamp       value
# 0  2013-10-09 16:25:00   9926554.0
# 1  2013-10-09 16:30:00  50745578.0
# 2  2013-10-09 16:35:00  61519397.0
# 3  2013-10-09 16:40:00  55996401.0
# 4  2013-10-09 16:45:00  40876988.0

# %%
print(NetworkIn['timestamp'].min())
print(NetworkIn['timestamp'].max())
print(len(NetworkIn['timestamp']))
# Out:
# 2013-10-09 16:25:00
# 2013-10-13 23:55:00
# 1243

# %%
NetworkIn.plot()
# Out:
# <AxesSubplot: >

# %%
rds_cpu_utilization_cc0c53 = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/rds_cpu_utilization_cc0c53.csv')
rds_cpu_utilization_cc0c53.head()
# Out:
#              timestamp  value
# 0  2014-02-14 14:30:00  6.456
# 1  2014-02-14 14:35:00  5.816
# 2  2014-02-14 14:40:00  6.268
# 3  2014-02-14 14:45:00  5.816
# 4  2014-02-14 14:50:00  5.862

# %%
print(rds_cpu_utilization_cc0c53['timestamp'].min())
print(rds_cpu_utilization_cc0c53['timestamp'].max())
print(len(rds_cpu_utilization_cc0c53['timestamp']))
# Out:
# 2014-02-14 14:30:00
# 2014-02-28 14:30:00
# 4032

# %%
rds_cpu_utilization_cc0c53.plot()
# Out:
# <AxesSubplot: >

# %%
rds_cpu_utilization_e47b3b = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realAWSCloudwatch/rds_cpu_utilization_e47b3b.csv')
rds_cpu_utilization_e47b3b.head()
# Out:
#              timestamp   value
# 0  2014-04-10 00:02:00  14.012
# 1  2014-04-10 00:07:00  13.334
# 2  2014-04-10 00:12:00  15.000
# 3  2014-04-10 00:17:00  13.998
# 4  2014-04-10 00:22:00  14.332

# %%
print(rds_cpu_utilization_e47b3b['timestamp'].min())
print(rds_cpu_utilization_e47b3b['timestamp'].max())
print(len(rds_cpu_utilization_e47b3b['timestamp']))
# Out:
# 2014-04-10 00:02:00
# 2014-04-23 23:57:00
# 4032

# %%
rds_cpu_utilization_e47b3b.plot()
# Out:
# <AxesSubplot: >
